# %%
import pandas as pd
data = pd.read_csv("data.csv", delimiter='\t')
print(data.columns.values)
# Out:
# ['Q1A' 'Q1I' 'Q1E' 'Q2A' 'Q2I' 'Q2E' 'Q3A' 'Q3I' 'Q3E' 'Q4A' 'Q4I' 'Q4E'
#  'Q5A' 'Q5I' 'Q5E' 'Q6A' 'Q6I' 'Q6E' 'Q7A' 'Q7I' 'Q7E' 'Q8A' 'Q8I' 'Q8E'
#  'Q9A' 'Q9I' 'Q9E' 'Q10A' 'Q10I' 'Q10E' 'Q11A' 'Q11I' 'Q11E' 'Q12A' 'Q12I'
#  'Q12E' 'Q13A' 'Q13I' 'Q13E' 'Q14A' 'Q14I' 'Q14E' 'Q15A' 'Q15I' 'Q15E'
#  'Q16A' 'Q16I' 'Q16E' 'Q17A' 'Q17I' 'Q17E' 'Q18A' 'Q18I' 'Q18E' 'Q19A'
#  'Q19I' 'Q19E' 'Q20A' 'Q20I' 'Q20E' 'Q21A' 'Q21I' 'Q21E' 'Q22A' 'Q22I'
#  'Q22E' 'Q23A' 'Q23I' 'Q23E' 'Q24A' 'Q24I' 'Q24E' 'Q25A' 'Q25I' 'Q25E'
#  'Q26A' 'Q26I' 'Q26E' 'Q27A' 'Q27I' 'Q27E' 'Q28A' 'Q28I' 'Q28E' 'Q29A'
#  'Q29I' 'Q29E' 'Q30A' 'Q30I' 'Q30E' 'Q31A' 'Q31I' 'Q31E' 'Q32A' 'Q32I'
#  'Q32E' 'Q33A' 'Q33I' 'Q33E' 'Q34A' 'Q34I' 'Q34E' 'Q35A' 'Q35I' 'Q35E'
#  'Q36A' 'Q36I' 'Q36E' 'Q37A' 'Q37I' 'Q37E' 'Q38A' 'Q38I' 'Q38E' 'Q39A'
#  'Q39I' 'Q39E' 'Q40A' 'Q40I' 'Q40E' 'Q41A' 'Q41I' 'Q41E' 'Q42A' 'Q42I'
#  'Q42E' 'country' 'source' 'introelapse' 'testelapse' 'surveyelapse'
# ...

# %%
df = data[[f'Q{i}A' for i in range(1, 43)]]
print(df.columns)
# Out:
# Index(['Q1A', 'Q2A', 'Q3A', 'Q4A', 'Q5A', 'Q6A', 'Q7A', 'Q8A', 'Q9A', 'Q10A',
#        'Q11A', 'Q12A', 'Q13A', 'Q14A', 'Q15A', 'Q16A', 'Q17A', 'Q18A', 'Q19A',
#        'Q20A', 'Q21A', 'Q22A', 'Q23A', 'Q24A', 'Q25A', 'Q26A', 'Q27A', 'Q28A',
#        'Q29A', 'Q30A', 'Q31A', 'Q32A', 'Q33A', 'Q34A', 'Q35A', 'Q36A', 'Q37A',
#        'Q38A', 'Q39A', 'Q40A', 'Q41A', 'Q42A'],
#       dtype='object')

# %%
df.columns = [f'Q{i}' for i in range(1, 43)]
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q33  Q34  Q35  Q36  Q37  Q38  \
# 0   4   4   2   4   4   4   4   4   2    1  ...    2    3    4    4    1    2
# 1   4   1   2   3   4   4   3   4   3    2  ...    3    2    2    3    4    2
# 2   3   1   4   1   4   3   1   3   2    4  ...    1    4    3    4    4    4
# 3   2   3   2   1   3   3   4   2   3    3  ...    2    4    1    1    2    1
# 4   2   2   3   4   4   2   4   4   4    3  ...    4    4    3    4    3    3
#
#    Q39  Q40  Q41  Q42
# 0    4    3    4    4
# 1    2    1    2    2
# 2    2    2    1    4
# 3    3    4    4    2
# 4    3    4    4    3
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (39775, 42)

# %%
df = df - 1
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q33  Q34  Q35  Q36  Q37  Q38  \
# 0   3   3   1   3   3   3   3   3   1    0  ...    1    2    3    3    0    1
# 1   3   0   1   2   3   3   2   3   2    1  ...    2    1    1    2    3    1
# 2   2   0   3   0   3   2   0   2   1    3  ...    0    3    2    3    3    3
# 3   1   2   1   0   2   2   3   1   2    2  ...    1    3    0    0    1    0
# 4   1   1   2   3   3   1   3   3   3    2  ...    3    3    2    3    2    2
#
#    Q39  Q40  Q41  Q42
# 0    3    2    3    3
# 1    1    0    1    1
# 2    1    1    0    3
# 3    2    3    3    1
# 4    2    3    3    2
#
# [5 rows x 42 columns]

# %%
anxiety_df = df[['Q2', 'Q4', 'Q7', 'Q9', 'Q15', 'Q19', 'Q20', 'Q23', 'Q25', 'Q28', 'Q30', 'Q36', 'Q40', 'Q41']]
stress_df = df[['Q1', 'Q6', 'Q8', 'Q11', 'Q12', 'Q14', 'Q18', 'Q22', 'Q27', 'Q29', 'Q32', 'Q33', 'Q35', 'Q39']]
depression_df = df[['Q3', 'Q5', 'Q10', 'Q13', 'Q16', 'Q17', 'Q21', 'Q24', 'Q26', 'Q31', 'Q34', 'Q37', 'Q38', 'Q42']]

# %%
anxiety_df.loc[:, 'WS'] = anxiety_df.sum(axis=1)
stress_df.loc[:, 'WS'] = stress_df.sum(axis=1)
depression_df.loc[:, 'WS'] = depression_df.sum(axis=1)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\2214969006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anxiety_df.loc[:, 'WS'] = anxiety_df.sum(axis=1)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\2214969006.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stress_df.loc[:, 'WS'] = stress_df.sum(axis=1)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\2214969006.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
anxiety_df.head()
# Out:
#    Q2  Q4  Q7  Q9  Q15  Q19  Q20  Q23  Q25  Q28  Q30  Q36  Q40  Q41  WS
# 0   3   3   3   1    3    2    2    3    3    2    1    3    2    3  34
# 1   0   2   2   2    2    0    0    0    1    3    2    2    0    1  17
# 2   0   0   0   1    3    1    0    1    1    0    1    3    1    0  12
# 3   2   0   3   2    1    0    1    0    0    0    2    0    3    3  17
# 4   1   3   3   3    3    3    3    3    3    3    3    3    3    3  40

# %%
bins = [0, 8, 10, 15, 20, float('inf')]
labels = [0, 1, 2, 3, 4]
anxiety_df['Classes'] = pd.cut(anxiety_df['WS'], bins=bins, labels=labels, right=False)
anxiety_df.head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\2346674480.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anxiety_df['Classes'] = pd.cut(anxiety_df['WS'], bins=bins, labels=labels, right=False)
#    Q2  Q4  Q7  Q9  Q15  Q19  Q20  Q23  Q25  Q28  Q30  Q36  Q40  Q41  WS  \
# 0   3   3   3   1    3    2    2    3    3    2    1    3    2    3  34
# 1   0   2   2   2    2    0    0    0    1    3    2    2    0    1  17
# 2   0   0   0   1    3    1    0    1    1    0    1    3    1    0  12
# 3   2   0   3   2    1    0    1    0    0    0    2    0    3    3  17
# 4   1   3   3   3    3    3    3    3    3    3    3    3    3    3  40
#
#   Classes
# 0       4
# 1       3
# 2       2
# 3       3
# 4       4

# %%
bins = [0, 15, 19, 26, 34, float('inf')]
labels = [0, 1, 2, 3, 4]
stress_df['Classes'] = pd.cut(stress_df['WS'], bins=bins, labels=labels, right=False)
stress_df.head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\2936054761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stress_df['Classes'] = pd.cut(stress_df['WS'], bins=bins, labels=labels, right=False)
#    Q1  Q6  Q8  Q11  Q12  Q14  Q18  Q22  Q27  Q29  Q32  Q33  Q35  Q39  WS  \
# 0   3   3   3    3    3    3    3    3    3    3    3    1    3    3  40
# 1   3   3   3    1    1    3    1    2    2    2    2    2    1    1  27
# 2   2   2   2    1    0    0    1    2    1    1    2    0    2    1  17
# 3   1   2   1    1    0    3    0    0    3    2    0    1    0    2  16
# 4   1   1   3    1    3    3    3    2    1    1    3    3    2    2  29
#
#   Classes
# 0       4
# 1       3
# 2       1
# 3       1
# 4       3

# %%
bins = [0, 10, 14, 21, 28, float('inf')]
labels = [0, 1, 2, 3, 4]
depression_df['Classes'] = pd.cut(depression_df['WS'], bins=bins, labels=labels, right=False)
depression_df.head()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\3523915276.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depression_df['Classes'] = pd.cut(depression_df['WS'], bins=bins, labels=labels, right=False)
#    Q3  Q5  Q10  Q13  Q16  Q17  Q21  Q24  Q26  Q31  Q34  Q37  Q38  Q42  WS  \
# 0   1   3    0    3    3    2    0    3    3    3    2    0    1    3  27
# 1   1   3    1    3    2    3    1    1    2    1    1    3    1    1  24
# 2   3   3    3    3    3    3    3    3    0    3    3    3    3    3  39
# 3   1   2    2    0    1    2    0    0    1    2    3    1    0    1  16
# 4   2   3    2    3    2    3    2    1    3    2    3    2    2    2  32
#
#   Classes
# 0       3
# 1       3
# 2       4
# 3       2
# 4       4

# %%
anxiety_df.drop('WS', axis=1, inplace=True)
stress_df.drop('WS', axis=1, inplace=True)
depression_df.drop('WS', axis=1, inplace=True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\2061786061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anxiety_df.drop('WS', axis=1, inplace=True)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\2061786061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stress_df.drop('WS', axis=1, inplace=True)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14668\2061786061.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
anxiety_df.to_csv('anxiety.csv', index=False)
stress_df.to_csv('stress.csv', index=False)
depression_df.to_csv('depression.csv', index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_classif

X = anxiety_df.drop(labels=['Classes', 'WS'], axis=1)
y = anxiety_df['Classes']

info_gain = mutual_info_classif(X, y)

# Create a DataFrame to store feature names and their information gain scores
feature_info_gain = pd.DataFrame({'Feature': X.columns, 'Information Gain': info_gain})

# Sort features based on information gain
feature_info_gain = feature_info_gain.sort_values(by='Information Gain', ascending=False)

print(feature_info_gain)

# Plot the information gain scores
plt.figure(figsize=(10, 6))
plt.barh(feature_info_gain['Feature'], feature_info_gain['Information Gain'], color='skyblue')
plt.xlabel('Information Gain')
plt.title('Feature Importance (Information Gain)')
plt.show()
# Out:
#    Feature  Information Gain
# 9      Q28          0.358914
# 6      Q20          0.338770
# 11     Q36          0.328359
# 12     Q40          0.315563
# 2       Q7          0.306787
# 3       Q9          0.306646
# 1       Q4          0.288413
# 13     Q41          0.278036
# 8      Q25          0.255937
# 10     Q30          0.255401
# 4      Q15          0.219196
# 5      Q19          0.186065
# 7      Q23          0.182184
# 0       Q2          0.160256

# %%
# X.drop(labels=['Q2', 'Q23', 'Q19'], axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

# %%
class_distribution = y_train.value_counts()

# Display the class distribution
print("Class Distribution:")
print(class_distribution)
# Out:
# Class Distribution:
# Classes
# 4    11308
# 0     7808
# 2     5579
# 3     4899
# 1     2226
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE
sampler = SMOTE()
X_train, y_train = sampler.fit_resample(X_train, y_train)

# %%
class_distribution = y_train.value_counts()

# Display the class distribution
print("Class Distribution:")
print(class_distribution)
# Out:
# Class Distribution:
# Classes
# 0    11308
# 1    11308
# 2    11308
# 3    11308
# 4    11308
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
dtclf = DecisionTreeClassifier(criterion='entropy')
dtclf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = dtclf.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90      1920
#            1       0.41      0.51      0.45       538
#            2       0.67      0.62      0.64      1469
#            3       0.56      0.66      0.60      1214
#            4       0.92      0.90      0.91      2814
#
#     accuracy                           0.77      7955
#    macro avg       0.70      0.71      0.70      7955
# weighted avg       0.79      0.77      0.78      7955

# %%
plot_tree(dtclf)
# Out:
# [Text(0.7182747174185986, 0.9814814814814815, 'x[9] <= 1.5\nentropy = 2.322\nsamples = 56540\nvalue = [11308, 11308, 11308, 11308, 11308]'),
#  Text(0.49132789516289016, 0.9444444444444444, 'x[2] <= 0.5\nentropy = 2.201\nsamples = 42075\nvalue = [11147, 10809, 9721, 7746, 2652]'),
#  Text(0.2883824822875121, 0.9074074074074074, 'x[12] <= 1.5\nentropy = 1.933\nsamples = 26816\nvalue = [10118, 8089, 5618, 2666, 325]'),
#  Text(0.15748736357760512, 0.8703703703703703, 'x[11] <= 0.5\nentropy = 1.644\nsamples = 19040\nvalue = [9389, 5984, 2868, 756, 43]'),
#  Text(0.06931388227951789, 0.8333333333333334, 'x[8] <= 0.5\nentropy = 1.223\nsamples = 10871\nvalue = [7372, 2586, 784, 128, 1]'),
#  Text(0.02478813783138953, 0.7962962962962963, 'x[3] <= 0.5\nentropy = 0.83\nsamples = 6715\nvalue = [5460, 1038, 203, 14, 0]'),
#  Text(0.008329432720937188, 0.7592592592592593, 'x[13] <= 0.5\nentropy = 0.345\nsamples = 3372\nvalue = [3179, 172, 21, 0, 0]'),
# ...
