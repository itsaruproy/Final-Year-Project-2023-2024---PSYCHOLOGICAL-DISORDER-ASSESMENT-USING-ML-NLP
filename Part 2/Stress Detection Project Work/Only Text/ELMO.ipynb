# %%
# !gdown 1XGLAnvZt9oEYCscQcqHjbva0k5S605BZ
# !gdown 1EEBfIUZD0q0wRXo8pPFnIGzlzaexI6si
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XGLAnvZt9oEYCscQcqHjbva0k5S605BZ
# To: /content/test_data.csv
# 100% 176k/176k [00:00<00:00, 72.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1EEBfIUZD0q0wRXo8pPFnIGzlzaexI6si
# To: /content/train_data.csv
# 100% 692k/692k [00:00<00:00, 36.6MB/s]

# %%
pip install --upgrade tensorflow-hub

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.layers import Input, Lambda, Dense, Dropout, Layer, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV

# %%
train_df = pd.read_csv("train_data.csv")
X_train = train_df['clean_text'].tolist()
y_train = train_df['target'].tolist()

# %%
test_df = pd.read_csv("test_data.csv")
X_test = test_df['clean_text'].tolist()
y_test = test_df['target'].tolist()

# %%
# elmo = hub.load("https://tfhub.dev/google/elmo/3").signatures["default"]

# %%
# elmo(tf.constant(["go hell man", "hell wrost place world"]))

# %%
elmo = hub.KerasLayer("https://tfhub.dev/google/elmo/3", signature='default', signature_outputs_as_dict=True)

# %%
elmo(tf.squeeze(tf.cast(["go hell man", "hell wrost place world"], tf.string)))['default']
# Out:
# <tf.Tensor: shape=(2, 1024), dtype=float32, numpy=
# array([[ 0.45859107, -0.5309581 ,  0.09181502, ..., -0.05945195,
#          0.6796574 , -0.18722355],
#        [ 0.3864336 , -0.36333314,  0.25561047, ..., -0.06183494,
#          0.93176365,  0.07429498]], dtype=float32)>

# %%
def ELMoEmbedding(x):
    return elmo(tf.squeeze(tf.cast(x, tf.string)))['default']

# %%
def embedding_generator(data):
  def batch_generator(data, batch_size):
      for i in range(0, len(data), batch_size):
          yield data[i:i + batch_size]

  batch_size = 100

  batched_embeddings = []

  for batch_strings in batch_generator(data, batch_size):
      batch_embeddings = ELMoEmbedding(batch_strings)
      batched_embeddings.append(batch_embeddings)

  return np.concatenate(batched_embeddings, axis=0)

# %%
X_train_embeddings = embedding_generator(X_train)

# %%
X_test_embeddings = embedding_generator(X_test)

# %%
print(X_train_embeddings.shape, X_test_embeddings.shape)
# Out:
# (2842, 1024) (711, 1024)

# %% [markdown]
# # Training and Testing

# %%
def training_and_prediction(training_model, X_train, X_test, y_train, y_test):
  model = training_model
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)
  recall = recall_score(y_test, y_pred)
  f1score = f1_score(y_test, y_pred)
  # print("Accuracy =", accuracy)
  # print("Confusion Matrix =\n", confusion_matrix(y_test, y_pred))
  # print(classification_report(y_test, y_pred))
  return {'Accuracy' : accuracy, 'Precision': precision, 'Recall' : recall, 'F1-Score' : f1score}

# %%
def get_report(y_test, y_pred):
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)
  recall = recall_score(y_test, y_pred)
  f1score = f1_score(y_test, y_pred)
  return {'Accuracy' : accuracy, 'Precision': precision, 'Recall' : recall, 'F1-Score' : f1score}

# %% [markdown]
# ## Naive Bayes

# %%
scaler = MinMaxScaler()
training_and_prediction(MultinomialNB(alpha=10), scaler.fit_transform(X_train_embeddings), scaler.fit_transform(X_test_embeddings), y_train, y_test)
# Out:
# {'Accuracy': 0.6680731364275668,
#  'Precision': 0.6326034063260341,
#  'Recall': 0.7536231884057971,
#  'F1-Score': 0.6878306878306879}

# %%
training_and_prediction(GaussianNB(), X_train_embeddings, X_test_embeddings, y_train, y_test)
# Out:
# {'Accuracy': 0.6638537271448663,
#  'Precision': 0.6292682926829268,
#  'Recall': 0.7478260869565218,
#  'F1-Score': 0.6834437086092715}

# %%
training_and_prediction(BernoulliNB(alpha=10), X_train_embeddings, X_test_embeddings, y_train, y_test)
# Out:
# {'Accuracy': 0.6751054852320675,
#  'Precision': 0.6439393939393939,
#  'Recall': 0.7391304347826086,
#  'F1-Score': 0.688259109311741}

# %% [markdown]
# ## SVM

# %%
training_and_prediction(SVC(C=3), X_train_embeddings, X_test_embeddings, y_train, y_test)
# Out:
# {'Accuracy': 0.7482419127988749,
#  'Precision': 0.7255434782608695,
#  'Recall': 0.7739130434782608,
#  'F1-Score': 0.7489481065918653}

# %% [markdown]
# ## Random Forest

# %%
training_and_prediction(RandomForestClassifier(), X_train_embeddings, X_test_embeddings, y_train, y_test)
# Out:
# {'Accuracy': 0.6863572433192686,
#  'Precision': 0.6540404040404041,
#  'Recall': 0.7507246376811594,
#  'F1-Score': 0.699055330634278}

# %% [markdown]
# ## Logistic Regression

# %%
training_and_prediction(LogisticRegression(max_iter=500, solver='saga'), X_train_embeddings, X_test_embeddings, y_train, y_test)
# Out:
# {'Accuracy': 0.7144866385372715,
#  'Precision': 0.7028571428571428,
#  'Recall': 0.7130434782608696,
#  'F1-Score': 0.7079136690647483}

# %% [markdown]
# ## Gradient Boosting

# %%
training_and_prediction(XGBClassifier(), X_train_embeddings, X_test_embeddings, y_train, y_test)
# Out:
# {'Accuracy': 0.7158931082981715,
#  'Precision': 0.6906666666666667,
#  'Recall': 0.7507246376811594,
#  'F1-Score': 0.7194444444444446}

# %% [markdown]
# ## ANN

# %%
X_train_embeddings
# Out:
# array([[ 0.15054145, -0.23045449,  0.07539876, ..., -0.02576121,
#          0.05825442, -0.13898185],
#        [ 0.3116423 , -0.13860574,  0.11634748, ..., -0.12212291,
#          0.39752665,  0.25772002],
#        [ 0.15665506, -0.21737473,  0.00180799, ...,  0.13307352,
#          0.23066385, -0.03902674],
#        ...,
#        [ 0.2207749 , -0.01463366,  0.14317514, ..., -0.04515651,
#          0.20261212,  0.11536255],
#        [ 0.28964156, -0.20121856,  0.08562777, ..., -0.14125249,
#          0.11452472,  0.24354057],
#        [ 0.13207194, -0.14568658,  0.26370496, ...,  0.00411364,
#          0.24496566, -0.09277743]], dtype=float32)

# %%
def ann_models(num_neurons_layer1, num_neurons_layer2, dropout_rate1, dropout_rate2):
    model_dense = Sequential()
    if dropout_rate1 > 0:
      model_dense.add(Dropout(dropout_rate1))
    model_dense.add(Dense(num_neurons_layer1, activation='relu'))
    if dropout_rate2 > 0:
      model_dense.add(Dropout(dropout_rate2))
    model_dense.add(Dense(num_neurons_layer2, activation='relu'))
    model_dense.add(Dense(1, activation='sigmoid'))
    model_dense.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model_dense.fit(X_train_embeddings, np.array(y_train), epochs=20, batch_size=32, verbose=0, callbacks=[early_stop], validation_data=(X_test_embeddings, np.array(y_test)))
    y_pred_dense = model_dense.predict(X_test_embeddings)
    y_pred_dense = (y_pred_dense > 0.5).astype(int)
    return [{'num_neurons_layer1': num_neurons_layer1, 'num_neurons_layer2': num_neurons_layer2, 'dropout_rate1': dropout_rate1, 'dropout_rate2':dropout_rate2}, get_report(y_test, y_pred_dense)]

# %%
for num_neurons_layer1 in [128, 64]:
  for num_neurons_layer2 in [64, 32]:
    for dropout_rate1 in [0.0, 0.1, 0.2, 0.3, 0.4]:
      for dropout_rate2 in [0.0, 0.1, 0.2, 0.3, 0.4]:
        print(ann_models(num_neurons_layer1, num_neurons_layer2, dropout_rate1, dropout_rate2))
# Out:
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.0}, {'Accuracy': 0.7383966244725738, 'Precision': 0.7097625329815304, 'Recall': 0.7797101449275362, 'F1-Score': 0.7430939226519337}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.1}, {'Accuracy': 0.7383966244725738, 'Precision': 0.7086614173228346, 'Recall': 0.782608695652174, 'F1-Score': 0.743801652892562}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.2}, {'Accuracy': 0.7369901547116737, 'Precision': 0.717032967032967, 'Recall': 0.7565217391304347, 'F1-Score': 0.7362482369534555}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.3}, {'Accuracy': 0.7271448663853727, 'Precision': 0.711484593837535, 'Recall': 0.736231884057971, 'F1-Score': 0.7236467236467237}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.4}, {'Accuracy': 0.7271448663853727, 'Precision': 0.6971279373368147, 'Recall': 0.7739130434782608, 'F1-Score': 0.7335164835164835}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.0}, {'Accuracy': 0.7271448663853727, 'Precision': 0.7138810198300283, 'Recall': 0.7304347826086957, 'F1-Score': 0.7220630372492837}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.1}, {'Accuracy': 0.7454289732770746, 'Precision': 0.731638418079096, 'Recall': 0.7507246376811594, 'F1-Score': 0.7410586552217453}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.2}, {'Accuracy': 0.7468354430379747, 'Precision': 0.7586206896551724, 'Recall': 0.7014492753623188, 'F1-Score': 0.7289156626506025}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.3}, {'Accuracy': 0.7440225035161744, 'Precision': 0.7257617728531855, 'Recall': 0.7594202898550725, 'F1-Score': 0.7422096317280452}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.4}, {'Accuracy': 0.7285513361462729, 'Precision': 0.7043010752688172, 'Recall': 0.7594202898550725, 'F1-Score': 0.7308228730822873}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.0}, {'Accuracy': 0.7327707454289732, 'Precision': 0.7220630372492837, 'Recall': 0.7304347826086957, 'F1-Score': 0.7262247838616714}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.1}, {'Accuracy': 0.7285513361462729, 'Precision': 0.7209302325581395, 'Recall': 0.7188405797101449, 'F1-Score': 0.7198838896952103}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.2}, {'Accuracy': 0.7341772151898734, 'Precision': 0.7166666666666667, 'Recall': 0.7478260869565218, 'F1-Score': 0.7319148936170212}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.3}, {'Accuracy': 0.7412095639943741, 'Precision': 0.7146666666666667, 'Recall': 0.7768115942028986, 'F1-Score': 0.7444444444444444}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.4}, {'Accuracy': 0.7412095639943741, 'Precision': 0.7158176943699732, 'Recall': 0.7739130434782608, 'F1-Score': 0.7437325905292479}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.0}, {'Accuracy': 0.7454289732770746, 'Precision': 0.7277777777777777, 'Recall': 0.7594202898550725, 'F1-Score': 0.7432624113475177}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.1}, {'Accuracy': 0.7313642756680732, 'Precision': 0.7047872340425532, 'Recall': 0.7681159420289855, 'F1-Score': 0.7350901525658806}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.2}, {'Accuracy': 0.739803094233474, 'Precision': 0.7469135802469136, 'Recall': 0.7014492753623188, 'F1-Score': 0.7234678624813154}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.3}, {'Accuracy': 0.7327707454289732, 'Precision': 0.7055702917771883, 'Recall': 0.7710144927536232, 'F1-Score': 0.7368421052631579}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.4}, {'Accuracy': 0.7355836849507735, 'Precision': 0.7460815047021944, 'Recall': 0.6898550724637681, 'F1-Score': 0.7168674698795181}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.0}, {'Accuracy': 0.7327707454289732, 'Precision': 0.739938080495356, 'Recall': 0.6927536231884058, 'F1-Score': 0.7155688622754491}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.1}, {'Accuracy': 0.7412095639943741, 'Precision': 0.7402985074626866, 'Recall': 0.7188405797101449, 'F1-Score': 0.7294117647058823}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.2}, {'Accuracy': 0.7426160337552743, 'Precision': 0.7410714285714286, 'Recall': 0.7217391304347827, 'F1-Score': 0.7312775330396476}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.3}, {'Accuracy': 0.7327707454289732, 'Precision': 0.6972010178117048, 'Recall': 0.7942028985507247, 'F1-Score': 0.7425474254742548}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.4}, {'Accuracy': 0.7271448663853727, 'Precision': 0.7337461300309598, 'Recall': 0.6869565217391305, 'F1-Score': 0.7095808383233533}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.0}, {'Accuracy': 0.7327707454289732, 'Precision': 0.7158774373259053, 'Recall': 0.744927536231884, 'F1-Score': 0.7301136363636364}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.1}, {'Accuracy': 0.7341772151898734, 'Precision': 0.7010309278350515, 'Recall': 0.7884057971014493, 'F1-Score': 0.7421555252387448}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.2}, {'Accuracy': 0.7327707454289732, 'Precision': 0.7370030581039755, 'Recall': 0.6985507246376812, 'F1-Score': 0.7172619047619048}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.3}, {'Accuracy': 0.729957805907173, 'Precision': 0.7050938337801609, 'Recall': 0.7623188405797101, 'F1-Score': 0.7325905292479108}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.4}, {'Accuracy': 0.7369901547116737, 'Precision': 0.7257142857142858, 'Recall': 0.736231884057971, 'F1-Score': 0.7309352517985612}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.0}, {'Accuracy': 0.7580872011251758, 'Precision': 0.7306666666666667, 'Recall': 0.7942028985507247, 'F1-Score': 0.7611111111111112}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.1}, {'Accuracy': 0.7440225035161744, 'Precision': 0.7052896725440806, 'Recall': 0.8115942028985508, 'F1-Score': 0.7547169811320755}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.2}, {'Accuracy': 0.7327707454289732, 'Precision': 0.723342939481268, 'Recall': 0.7275362318840579, 'F1-Score': 0.7254335260115607}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.3}, {'Accuracy': 0.729957805907173, 'Precision': 0.7283582089552239, 'Recall': 0.7072463768115942, 'F1-Score': 0.7176470588235294}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.4}, {'Accuracy': 0.7369901547116737, 'Precision': 0.7206703910614525, 'Recall': 0.7478260869565218, 'F1-Score': 0.7339971550497867}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.0}, {'Accuracy': 0.7454289732770746, 'Precision': 0.7216216216216216, 'Recall': 0.7739130434782608, 'F1-Score': 0.7468531468531467}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.1}, {'Accuracy': 0.7327707454289732, 'Precision': 0.7034120734908137, 'Recall': 0.7768115942028986, 'F1-Score': 0.7382920110192838}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.2}, {'Accuracy': 0.7271448663853727, 'Precision': 0.7103064066852368, 'Recall': 0.7391304347826086, 'F1-Score': 0.7244318181818182}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.3}, {'Accuracy': 0.7355836849507735, 'Precision': 0.7400611620795107, 'Recall': 0.7014492753623188, 'F1-Score': 0.7202380952380952}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.4}, {'Accuracy': 0.7243319268635724, 'Precision': 0.718475073313783, 'Recall': 0.7101449275362319, 'F1-Score': 0.7142857142857143}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.0}, {'Accuracy': 0.7355836849507735, 'Precision': 0.710455764075067, 'Recall': 0.7681159420289855, 'F1-Score': 0.7381615598885793}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.1}, {'Accuracy': 0.739803094233474, 'Precision': 0.7247191011235955, 'Recall': 0.7478260869565218, 'F1-Score': 0.7360912981455064}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.2}, {'Accuracy': 0.739803094233474, 'Precision': 0.7272727272727273, 'Recall': 0.7420289855072464, 'F1-Score': 0.7345767575322812}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.3}, {'Accuracy': 0.7313642756680732, 'Precision': 0.7037037037037037, 'Recall': 0.7710144927536232, 'F1-Score': 0.73582295988935}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.4}, {'Accuracy': 0.7341772151898734, 'Precision': 0.7096774193548387, 'Recall': 0.7652173913043478, 'F1-Score': 0.7364016736401674}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.0}, {'Accuracy': 0.7271448663853727, 'Precision': 0.6940874035989717, 'Recall': 0.782608695652174, 'F1-Score': 0.7356948228882835}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.1}, {'Accuracy': 0.7313642756680732, 'Precision': 0.7015706806282722, 'Recall': 0.7768115942028986, 'F1-Score': 0.7372764786795049}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.2}, {'Accuracy': 0.7383966244725738, 'Precision': 0.712, 'Recall': 0.7739130434782608, 'F1-Score': 0.7416666666666666}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.3}, {'Accuracy': 0.7412095639943741, 'Precision': 0.7507788161993769, 'Recall': 0.6985507246376812, 'F1-Score': 0.7237237237237237}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.4}, {'Accuracy': 0.7383966244725738, 'Precision': 0.729106628242075, 'Recall': 0.7333333333333333, 'F1-Score': 0.7312138728323699}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.0}, {'Accuracy': 0.7482419127988749, 'Precision': 0.728021978021978, 'Recall': 0.7681159420289855, 'F1-Score': 0.7475317348377997}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.1}, {'Accuracy': 0.7355836849507735, 'Precision': 0.7507987220447284, 'Recall': 0.6811594202898551, 'F1-Score': 0.7142857142857142}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.2}, {'Accuracy': 0.7327707454289732, 'Precision': 0.7313432835820896, 'Recall': 0.7101449275362319, 'F1-Score': 0.7205882352941175}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.3}, {'Accuracy': 0.7383966244725738, 'Precision': 0.7345132743362832, 'Recall': 0.7217391304347827, 'F1-Score': 0.7280701754385965}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.0, 'dropout_rate2': 0.4}, {'Accuracy': 0.729957805907173, 'Precision': 0.6976744186046512, 'Recall': 0.782608695652174, 'F1-Score': 0.7377049180327868}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.0}, {'Accuracy': 0.729957805907173, 'Precision': 0.6987012987012987, 'Recall': 0.7797101449275362, 'F1-Score': 0.7369863013698631}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.1}, {'Accuracy': 0.7383966244725738, 'Precision': 0.7108753315649867, 'Recall': 0.7768115942028986, 'F1-Score': 0.7423822714681441}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.2}, {'Accuracy': 0.729957805907173, 'Precision': 0.6997389033942559, 'Recall': 0.7768115942028986, 'F1-Score': 0.7362637362637362}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.3}, {'Accuracy': 0.7285513361462729, 'Precision': 0.7054054054054054, 'Recall': 0.7565217391304347, 'F1-Score': 0.73006993006993}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.1, 'dropout_rate2': 0.4}, {'Accuracy': 0.7215189873417721, 'Precision': 0.7058823529411765, 'Recall': 0.7304347826086957, 'F1-Score': 0.7179487179487181}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.0}, {'Accuracy': 0.7355836849507735, 'Precision': 0.7060367454068242, 'Recall': 0.7797101449275362, 'F1-Score': 0.7410468319559229}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.1}, {'Accuracy': 0.7426160337552743, 'Precision': 0.7076923076923077, 'Recall': 0.8, 'F1-Score': 0.7510204081632654}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.2}, {'Accuracy': 0.7355836849507735, 'Precision': 0.760797342192691, 'Recall': 0.663768115942029, 'F1-Score': 0.7089783281733747}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.3}, {'Accuracy': 0.739803094233474, 'Precision': 0.723463687150838, 'Recall': 0.7507246376811594, 'F1-Score': 0.736842105263158}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.2, 'dropout_rate2': 0.4}, {'Accuracy': 0.7313642756680732, 'Precision': 0.7333333333333333, 'Recall': 0.7014492753623188, 'F1-Score': 0.7170370370370369}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.0}, {'Accuracy': 0.7468354430379747, 'Precision': 0.7285318559556787, 'Recall': 0.7623188405797101, 'F1-Score': 0.745042492917847}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.1}, {'Accuracy': 0.729957805907173, 'Precision': 0.7217391304347827, 'Recall': 0.7217391304347827, 'F1-Score': 0.7217391304347827}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.2}, {'Accuracy': 0.7243319268635724, 'Precision': 0.7086834733893558, 'Recall': 0.7333333333333333, 'F1-Score': 0.7207977207977209}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.3}, {'Accuracy': 0.729957805907173, 'Precision': 0.7191977077363897, 'Recall': 0.7275362318840579, 'F1-Score': 0.7233429394812679}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.3, 'dropout_rate2': 0.4}, {'Accuracy': 0.7187060478199718, 'Precision': 0.7126099706744868, 'Recall': 0.7043478260869566, 'F1-Score': 0.7084548104956269}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.0}, {'Accuracy': 0.739803094233474, 'Precision': 0.7380952380952381, 'Recall': 0.7188405797101449, 'F1-Score': 0.7283406754772394}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.1}, {'Accuracy': 0.7355836849507735, 'Precision': 0.7186629526462396, 'Recall': 0.7478260869565218, 'F1-Score': 0.7329545454545455}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.2}, {'Accuracy': 0.7341772151898734, 'Precision': 0.6959798994974874, 'Recall': 0.8028985507246377, 'F1-Score': 0.7456258411843876}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.3}, {'Accuracy': 0.720112517580872, 'Precision': 0.7050561797752809, 'Recall': 0.7275362318840579, 'F1-Score': 0.7161198288159771}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate1': 0.4, 'dropout_rate2': 0.4}, {'Accuracy': 0.7074542897327707, 'Precision': 0.709480122324159, 'Recall': 0.672463768115942, 'F1-Score': 0.6904761904761906}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.0}, {'Accuracy': 0.7440225035161744, 'Precision': 0.7084398976982097, 'Recall': 0.8028985507246377, 'F1-Score': 0.7527173913043478}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.1}, {'Accuracy': 0.7369901547116737, 'Precision': 0.7194444444444444, 'Recall': 0.7507246376811594, 'F1-Score': 0.7347517730496453}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.2}, {'Accuracy': 0.7215189873417721, 'Precision': 0.7106017191977078, 'Recall': 0.7188405797101449, 'F1-Score': 0.7146974063400577}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.3}, {'Accuracy': 0.729957805907173, 'Precision': 0.7283582089552239, 'Recall': 0.7072463768115942, 'F1-Score': 0.7176470588235294}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.0, 'dropout_rate2': 0.4}, {'Accuracy': 0.7313642756680732, 'Precision': 0.7081081081081081, 'Recall': 0.7594202898550725, 'F1-Score': 0.7328671328671329}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.0}, {'Accuracy': 0.7341772151898734, 'Precision': 0.7074468085106383, 'Recall': 0.7710144927536232, 'F1-Score': 0.7378640776699029}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.1}, {'Accuracy': 0.749648382559775, 'Precision': 0.7448680351906158, 'Recall': 0.736231884057971, 'F1-Score': 0.7405247813411078}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.2}, {'Accuracy': 0.7243319268635724, 'Precision': 0.7237237237237237, 'Recall': 0.6985507246376812, 'F1-Score': 0.7109144542772862}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.3}, {'Accuracy': 0.7285513361462729, 'Precision': 0.7196531791907514, 'Recall': 0.7217391304347827, 'F1-Score': 0.7206946454413893}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.1, 'dropout_rate2': 0.4}, {'Accuracy': 0.7285513361462729, 'Precision': 0.7111111111111111, 'Recall': 0.7420289855072464, 'F1-Score': 0.7262411347517731}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.0}, {'Accuracy': 0.739803094233474, 'Precision': 0.7515723270440252, 'Recall': 0.6927536231884058, 'F1-Score': 0.7209653092006034}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.1}, {'Accuracy': 0.7313642756680732, 'Precision': 0.7305389221556886, 'Recall': 0.7072463768115942, 'F1-Score': 0.7187039764359352}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.2}, {'Accuracy': 0.7313642756680732, 'Precision': 0.7005208333333334, 'Recall': 0.7797101449275362, 'F1-Score': 0.7379972565157751}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.3}, {'Accuracy': 0.7285513361462729, 'Precision': 0.701058201058201, 'Recall': 0.7681159420289855, 'F1-Score': 0.7330567081604427}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.2, 'dropout_rate2': 0.4}, {'Accuracy': 0.7412095639943741, 'Precision': 0.7293447293447294, 'Recall': 0.7420289855072464, 'F1-Score': 0.735632183908046}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.0}, {'Accuracy': 0.729957805907173, 'Precision': 0.7095890410958904, 'Recall': 0.7507246376811594, 'F1-Score': 0.7295774647887323}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.1}, {'Accuracy': 0.7327707454289732, 'Precision': 0.7111716621253406, 'Recall': 0.7565217391304347, 'F1-Score': 0.7331460674157302}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.2}, {'Accuracy': 0.7369901547116737, 'Precision': 0.7379518072289156, 'Recall': 0.7101449275362319, 'F1-Score': 0.723781388478582}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.3}, {'Accuracy': 0.7327707454289732, 'Precision': 0.7429467084639498, 'Recall': 0.6869565217391305, 'F1-Score': 0.713855421686747}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.3, 'dropout_rate2': 0.4}, {'Accuracy': 0.7313642756680732, 'Precision': 0.6925, 'Recall': 0.8028985507246377, 'F1-Score': 0.7436241610738255}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.0}, {'Accuracy': 0.7243319268635724, 'Precision': 0.7159420289855073, 'Recall': 0.7159420289855073, 'F1-Score': 0.7159420289855073}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.1}, {'Accuracy': 0.7215189873417721, 'Precision': 0.7082152974504249, 'Recall': 0.7246376811594203, 'F1-Score': 0.7163323782234956}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.2}, {'Accuracy': 0.7440225035161744, 'Precision': 0.7196765498652291, 'Recall': 0.7739130434782608, 'F1-Score': 0.7458100558659218}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.3}, {'Accuracy': 0.7341772151898734, 'Precision': 0.7154696132596685, 'Recall': 0.7507246376811594, 'F1-Score': 0.7326732673267327}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate1': 0.4, 'dropout_rate2': 0.4}, {'Accuracy': 0.6962025316455697, 'Precision': 0.6449438202247191, 'Recall': 0.8318840579710145, 'F1-Score': 0.7265822784810126}]
