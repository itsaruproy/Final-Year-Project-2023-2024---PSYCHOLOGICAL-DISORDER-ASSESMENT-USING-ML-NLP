# %%
# !gdown 1OS2Aurb2oKmooCeYwYw0cnp542t7dyHo
# !gdown 1Oibb4sFzJNLt0iBWOD4LAIKaWT7cCNT1
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OS2Aurb2oKmooCeYwYw0cnp542t7dyHo
# To: /content/test_data.csv
# 100% 565k/565k [00:00<00:00, 76.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Oibb4sFzJNLt0iBWOD4LAIKaWT7cCNT1
# To: /content/train_data.csv
# 100% 2.24M/2.24M [00:00<00:00, 135MB/s]

# %%
import numpy as np
import pandas as pd
import gensim
import gensim.downloader as api
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV

# %%
train_df = pd.read_csv("train_data.csv")
test_df = pd.read_csv("test_data.csv")

# %%
train_df = train_df[train_df['confidence'] >= 0.8].reset_index(drop=True)

# %%
train_df.shape
# Out:
# (1832, 111)

# %%
test_df = test_df[test_df['confidence'] >= 0.8].reset_index(drop=True)
test_df.shape
# Out:
# (465, 111)

# %%
X_train = train_df['clean_text'].to_numpy()
y_train = train_df['target'].to_numpy()

# %%
X_test = test_df['clean_text'].to_numpy()
y_test = test_df['target'].to_numpy()

# %% [markdown]
# # Pretrained Fasttext

# %%
path = api.load("fasttext-wiki-news-subwords-300", return_path=True)
print(path)
# Out:
# [==================================================] 100.0% 958.5/958.4MB downloaded
# /root/gensim-data/fasttext-wiki-news-subwords-300/fasttext-wiki-news-subwords-300.gz

# %%
model_fasttext = gensim.models.KeyedVectors.load_word2vec_format(path)

# %%
voc = set(model_fasttext.index_to_key)
def document_vector(doc):
    doc = doc.split()
    doc = [word for word in doc if word in voc]
    return np.mean(model_fasttext[doc], axis=0)

# %%
X_train_fasttext = []
for review in X_train:
    X_train_fasttext.append(document_vector(review))

# %%
X_test_fasttext = []
for review in X_test:
    X_test_fasttext.append(document_vector(review))

# %%
np.array(X_train_fasttext).shape
# Out:
# (1832, 300)

# %% [markdown]
# # Training and Testing

# %%
def training_and_prediction(training_model, X_train, X_test, y_train, y_test):
  model = training_model
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)
  recall = recall_score(y_test, y_pred)
  f1score = f1_score(y_test, y_pred)
  # print("Accuracy =", accuracy)
  # print("Confusion Matrix =\n", confusion_matrix(y_test, y_pred))
  # print(classification_report(y_test, y_pred))
  return {'Accuracy' : accuracy, 'Precision': precision, 'Recall' : recall, 'F1-Score' : f1score}

# %%
def get_report(y_test, y_pred):
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)
  recall = recall_score(y_test, y_pred)
  f1score = f1_score(y_test, y_pred)
  return {'Accuracy' : accuracy, 'Precision': precision, 'Recall' : recall, 'F1-Score' : f1score}

# %% [markdown]
# ## Naive Bayes

# %%
scaler = MinMaxScaler()
training_and_prediction(MultinomialNB(), scaler.fit_transform(X_train_fasttext), scaler.fit_transform(X_test_fasttext), y_train, y_test)
# Out:
# {'Accuracy': 0.7268817204301076,
#  'Precision': 0.7215686274509804,
#  'Recall': 0.7666666666666667,
#  'F1-Score': 0.7434343434343434}

# %%
training_and_prediction(GaussianNB(), X_train_fasttext, X_test_fasttext, y_train, y_test)
# Out:
# {'Accuracy': 0.7290322580645161,
#  'Precision': 0.7111111111111111,
#  'Recall': 0.8,
#  'F1-Score': 0.7529411764705882}

# %%
training_and_prediction(BernoulliNB(), X_train_fasttext, X_test_fasttext, y_train, y_test)
# Out:
# {'Accuracy': 0.7397849462365591,
#  'Precision': 0.7428571428571429,
#  'Recall': 0.7583333333333333,
#  'F1-Score': 0.7505154639175258}

# %% [markdown]
# ## SVM

# %%
training_and_prediction(SVC(C=10), X_train_fasttext, X_test_fasttext, y_train, y_test)
# Out:
# {'Accuracy': 0.7956989247311828,
#  'Precision': 0.7865612648221344,
#  'Recall': 0.8291666666666667,
#  'F1-Score': 0.8073022312373225}

# %%
training_and_prediction(SVC(kernel='poly', C=5), X_train_fasttext, X_test_fasttext, y_train, y_test)
# Out:
# {'Accuracy': 0.7956989247311828,
#  'Precision': 0.7865612648221344,
#  'Recall': 0.8291666666666667,
#  'F1-Score': 0.8073022312373225}

# %% [markdown]
# ## Random Forest

# %%
training_and_prediction(RandomForestClassifier(), X_train_fasttext, X_test_fasttext, y_train, y_test)
# Out:
# {'Accuracy': 0.7634408602150538,
#  'Precision': 0.7462121212121212,
#  'Recall': 0.8208333333333333,
#  'F1-Score': 0.7817460317460317}

# %% [markdown]
# ## Logistic Regression

# %%
training_and_prediction(LogisticRegression(penalty='l2', C=10, solver='saga'), X_train_fasttext, X_test_fasttext, y_train, y_test)
# Out:
# {'Accuracy': 0.7978494623655914,
#  'Precision': 0.7829457364341085,
#  'Recall': 0.8416666666666667,
#  'F1-Score': 0.8112449799196787}

# %% [markdown]
# ## Gradient Boosting

# %%
training_and_prediction(XGBClassifier(), X_train_fasttext, X_test_fasttext, y_train, y_test)
# Out:
# {'Accuracy': 0.7849462365591398,
#  'Precision': 0.7713178294573644,
#  'Recall': 0.8291666666666667,
#  'F1-Score': 0.7991967871485945}

# %% [markdown]
# ## Deep Learning Techniques with Word2vec

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Bidirectional, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Tokenize text data
tokenizer = Tokenizer(num_words=7000)
tokenizer.fit_on_texts(np.concatenate((X_train, X_test), axis=0))
X_train_sequences = tokenizer.texts_to_sequences(X_train)
X_test_sequences = tokenizer.texts_to_sequences(X_test)

# %%
high = 0
for temp in X_train_sequences:
  high = max(high, len(temp))
high
# Out:
# 141

# %%
# Pad sequences to same length
max_len = 150
X_train_padded_sequences = pad_sequences(X_train_sequences, maxlen=max_len)
X_test_padded_sequences = pad_sequences(X_test_sequences, maxlen=max_len)

# %%
# Create embedding layer
embedding_dim = 300
embedding_matrix = np.zeros((len(tokenizer.word_index) + 1, embedding_dim))
for word, i in tokenizer.word_index.items():
    if word in model_fasttext:
        embedding_matrix[i] = model_fasttext[word]
embedding_layer = Embedding(len(tokenizer.word_index) + 1, embedding_dim, weights=[embedding_matrix], trainable=False)

# %% [markdown]
# ### ANN

# %%
def ann_models(num_neurons_layer1, num_neurons_layer2=0, dropout_rate=0):
    model_dense = Sequential()
    model_dense.add(embedding_layer)
    model_dense.add(GlobalAveragePooling1D())
    model_dense.add(Dense(num_neurons_layer1, activation='relu'))
    model_dense.add(Dropout(dropout_rate))
    if num_neurons_layer2 > 0:
      model_dense.add(Dense(num_neurons_layer2, activation='relu'))
    model_dense.add(Dense(1, activation='sigmoid'))
    model_dense.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model_dense.fit(X_train_padded_sequences, y_train, epochs=100, batch_size=32, verbose=0, callbacks=[early_stop], validation_data=(X_test_padded_sequences, y_test))
    y_pred_dense = model_dense.predict(X_test_padded_sequences)
    y_pred_dense = (y_pred_dense > 0.5).astype(int)
    return [{'num_neurons_layer1': num_neurons_layer1, 'num_neurons_layer2': num_neurons_layer2, 'dropout_rate': dropout_rate}, get_report(y_test, y_pred_dense)]

# %%
for num_neurons_layer1 in [128, 64]:
  for num_neurons_layer2 in [64, 32]:
    for dropout_rate in [0.0, 0.1, 0.2, 0.3, 0.4]:
      print(ann_models(num_neurons_layer1, num_neurons_layer2, dropout_rate))
# Out:
# 15/15 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.0}, {'Accuracy': 0.8064516129032258, 'Precision': 0.8, 'Recall': 0.8333333333333334, 'F1-Score': 0.816326530612245}]
# 15/15 [==============================] - 0s 6ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.1}, {'Accuracy': 0.8064516129032258, 'Precision': 0.8073770491803278, 'Recall': 0.8208333333333333, 'F1-Score': 0.8140495867768595}]
# 15/15 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.2}, {'Accuracy': 0.8150537634408602, 'Precision': 0.826271186440678, 'Recall': 0.8125, 'F1-Score': 0.819327731092437}]
# 15/15 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.3}, {'Accuracy': 0.8064516129032258, 'Precision': 0.7884615384615384, 'Recall': 0.8541666666666666, 'F1-Score': 0.8200000000000001}]
# 15/15 [==============================] - 0s 5ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.4}, {'Accuracy': 0.8064516129032258, 'Precision': 0.8073770491803278, 'Recall': 0.8208333333333333, 'F1-Score': 0.8140495867768595}]
# 15/15 [==============================] - 0s 5ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.0}, {'Accuracy': 0.8086021505376344, 'Precision': 0.796078431372549, 'Recall': 0.8458333333333333, 'F1-Score': 0.8202020202020202}]
# 15/15 [==============================] - 0s 6ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.1}, {'Accuracy': 0.8043010752688172, 'Precision': 0.8016194331983806, 'Recall': 0.825, 'F1-Score': 0.813141683778234}]
# 15/15 [==============================] - 0s 6ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.2}, {'Accuracy': 0.8172043010752689, 'Precision': 0.8112449799196787, 'Recall': 0.8416666666666667, 'F1-Score': 0.8261758691206544}]
# 15/15 [==============================] - 0s 7ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.3}, {'Accuracy': 0.8043010752688172, 'Precision': 0.7876447876447876, 'Recall': 0.85, 'F1-Score': 0.8176352705410822}]
# 15/15 [==============================] - 0s 5ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.4}, {'Accuracy': 0.8021505376344086, 'Precision': 0.8057851239669421, 'Recall': 0.8125, 'F1-Score': 0.8091286307053941}]
# 15/15 [==============================] - 0s 5ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.0}, {'Accuracy': 0.8064516129032258, 'Precision': 0.8, 'Recall': 0.8333333333333334, 'F1-Score': 0.816326530612245}]
# 15/15 [==============================] - 0s 6ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.1}, {'Accuracy': 0.8064516129032258, 'Precision': 0.8151260504201681, 'Recall': 0.8083333333333333, 'F1-Score': 0.8117154811715481}]
# 15/15 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.2}, {'Accuracy': 0.8129032258064516, 'Precision': 0.8148148148148148, 'Recall': 0.825, 'F1-Score': 0.8198757763975155}]
# 15/15 [==============================] - 0s 9ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.3}, {'Accuracy': 0.8043010752688172, 'Precision': 0.7991967871485943, 'Recall': 0.8291666666666667, 'F1-Score': 0.8139059304703475}]
# 15/15 [==============================] - 0s 6ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.4}, {'Accuracy': 0.8021505376344086, 'Precision': 0.7868217054263565, 'Recall': 0.8458333333333333, 'F1-Score': 0.8152610441767068}]
# 15/15 [==============================] - 0s 5ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.0}, {'Accuracy': 0.8086021505376344, 'Precision': 0.7937743190661478, 'Recall': 0.85, 'F1-Score': 0.8209255533199195}]
# 15/15 [==============================] - 0s 5ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.1}, {'Accuracy': 0.8064516129032258, 'Precision': 0.8024193548387096, 'Recall': 0.8291666666666667, 'F1-Score': 0.8155737704918032}]
# 15/15 [==============================] - 0s 6ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.2}, {'Accuracy': 0.8064516129032258, 'Precision': 0.7976190476190477, 'Recall': 0.8375, 'F1-Score': 0.8170731707317073}]
# 15/15 [==============================] - 0s 5ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.3}, {'Accuracy': 0.8043010752688172, 'Precision': 0.796812749003984, 'Recall': 0.8333333333333334, 'F1-Score': 0.814663951120163}]
# 15/15 [==============================] - 0s 9ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.4}, {'Accuracy': 0.810752688172043, 'Precision': 0.7992125984251969, 'Recall': 0.8458333333333333, 'F1-Score': 0.8218623481781376}]

# %% [markdown]
# ### LSTM

# %%
def lstm_models(num_neurons_layer1, dropout_rate=0):
    model_lstm = Sequential()
    model_lstm.add(embedding_layer)
    model_lstm.add(LSTM(128, dropout=dropout_rate))
    model_lstm.add(Dense(1, activation='sigmoid'))
    model_lstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    model_lstm.fit(X_train_padded_sequences, y_train, epochs=20, batch_size=32, verbose=0, callbacks=[early_stop], validation_data=(X_test_padded_sequences, y_test))
    y_pred_lstm = model_lstm.predict(X_test_padded_sequences)
    y_pred_lstm = (y_pred_lstm > 0.5).astype(int)
    return [{'num_neurons_layer1': num_neurons_layer1, 'dropout_rate': dropout_rate}, get_report(y_test, y_pred_lstm)]

# %%
for num_neurons_layer1 in [128, 64]:
  for dropout_rate in [0.0, 0.1, 0.2, 0.3, 0.4]:
    print(lstm_models(num_neurons_layer1, dropout_rate))
# Out:
# 15/15 [==============================] - 2s 93ms/step
# [{'num_neurons_layer1': 128, 'dropout_rate': 0.0}, {'Accuracy': 0.8021505376344086, 'Precision': 0.8083333333333333, 'Recall': 0.8083333333333333, 'F1-Score': 0.8083333333333333}]
# 15/15 [==============================] - 2s 94ms/step
# [{'num_neurons_layer1': 128, 'dropout_rate': 0.1}, {'Accuracy': 0.8064516129032258, 'Precision': 0.8151260504201681, 'Recall': 0.8083333333333333, 'F1-Score': 0.8117154811715481}]
# 15/15 [==============================] - 2s 92ms/step
# [{'num_neurons_layer1': 128, 'dropout_rate': 0.2}, {'Accuracy': 0.8043010752688172, 'Precision': 0.792156862745098, 'Recall': 0.8416666666666667, 'F1-Score': 0.8161616161616161}]
# 15/15 [==============================] - 2s 93ms/step
# [{'num_neurons_layer1': 128, 'dropout_rate': 0.3}, {'Accuracy': 0.789247311827957, 'Precision': 0.7817460317460317, 'Recall': 0.8208333333333333, 'F1-Score': 0.8008130081300813}]
# 15/15 [==============================] - 2s 93ms/step
# [{'num_neurons_layer1': 128, 'dropout_rate': 0.4}, {'Accuracy': 0.7913978494623656, 'Precision': 0.7677902621722846, 'Recall': 0.8541666666666666, 'F1-Score': 0.8086785009861932}]
# 15/15 [==============================] - 2s 98ms/step
# [{'num_neurons_layer1': 64, 'dropout_rate': 0.0}, {'Accuracy': 0.8064516129032258, 'Precision': 0.7884615384615384, 'Recall': 0.8541666666666666, 'F1-Score': 0.8200000000000001}]
# 15/15 [==============================] - 2s 92ms/step
# [{'num_neurons_layer1': 64, 'dropout_rate': 0.1}, {'Accuracy': 0.8, 'Precision': 0.7975708502024291, 'Recall': 0.8208333333333333, 'F1-Score': 0.8090349075975358}]
# 15/15 [==============================] - 3s 145ms/step
# [{'num_neurons_layer1': 64, 'dropout_rate': 0.2}, {'Accuracy': 0.8021505376344086, 'Precision': 0.7936507936507936, 'Recall': 0.8333333333333334, 'F1-Score': 0.8130081300813008}]
# 15/15 [==============================] - 2s 104ms/step
# [{'num_neurons_layer1': 64, 'dropout_rate': 0.3}, {'Accuracy': 0.7591397849462366, 'Precision': 0.714765100671141, 'Recall': 0.8875, 'F1-Score': 0.7918215613382901}]
# 15/15 [==============================] - 2s 101ms/step
# [{'num_neurons_layer1': 64, 'dropout_rate': 0.4}, {'Accuracy': 0.7913978494623656, 'Precision': 0.7848605577689243, 'Recall': 0.8208333333333333, 'F1-Score': 0.8024439918533605}]

# %% [markdown]
# ### Bidirectional LSTM

# %%
def bilstm_models(num_neurons_layer1, spatial_dropout_rate=0, dropout_rate=0):
    model_bilstm = Sequential()
    model_bilstm.add(embedding_layer)
    model_bilstm.add(SpatialDropout1D(spatial_dropout_rate))
    model_bilstm.add(Bidirectional(LSTM(num_neurons_layer1, return_sequences=False)))
    model_bilstm.add(Dropout(dropout_rate))
    model_bilstm.add(Dense(1, activation='sigmoid'))
    model_bilstm.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    model_bilstm.fit(X_train_padded_sequences, y_train, epochs=10, batch_size=32, verbose=0, callbacks=[early_stop], validation_data=(X_test_padded_sequences, y_test))
    y_pred_bilstm = model_bilstm.predict(X_test_padded_sequences)
    y_pred_bilstm = (y_pred_bilstm > 0.5).astype(int)
    return [{'num_neurons_layer1': num_neurons_layer1, 'spatial_dropout_rate': spatial_dropout_rate, 'dropout_rate': dropout_rate}, get_report(y_test, y_pred_bilstm)]

# %%
for num_neurons_layer1 in [128, 64]:
  for spatial_dropout_rate in [0, 0.2]:
    for dropout_rate in [0, 0.1, 0.2, 0.3, 0.4]:
      print(bilstm_models(num_neurons_layer1, spatial_dropout_rate, dropout_rate))
# Out:
# 15/15 [==============================] - 5s 208ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0, 'dropout_rate': 0}, {'Accuracy': 0.7677419354838709, 'Precision': 0.7214765100671141, 'Recall': 0.8958333333333334, 'F1-Score': 0.7992565055762082}]
# 15/15 [==============================] - 4s 197ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0, 'dropout_rate': 0.1}, {'Accuracy': 0.7827956989247312, 'Precision': 0.740484429065744, 'Recall': 0.8916666666666667, 'F1-Score': 0.8090737240075614}]
# 15/15 [==============================] - 3s 161ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0, 'dropout_rate': 0.2}, {'Accuracy': 0.7784946236559139, 'Precision': 0.7306397306397306, 'Recall': 0.9041666666666667, 'F1-Score': 0.8081936685288641}]
# 15/15 [==============================] - 4s 240ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0, 'dropout_rate': 0.3}, {'Accuracy': 0.7870967741935484, 'Precision': 0.8105726872246696, 'Recall': 0.7666666666666667, 'F1-Score': 0.7880085653104925}]
# 15/15 [==============================] - 4s 173ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0, 'dropout_rate': 0.4}, {'Accuracy': 0.789247311827957, 'Precision': 0.7448275862068966, 'Recall': 0.9, 'F1-Score': 0.8150943396226416}]
# 15/15 [==============================] - 3s 160ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0}, {'Accuracy': 0.7827956989247312, 'Precision': 0.7747035573122529, 'Recall': 0.8166666666666667, 'F1-Score': 0.795131845841785}]
# 15/15 [==============================] - 3s 176ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0.1}, {'Accuracy': 0.7978494623655914, 'Precision': 0.8067226890756303, 'Recall': 0.8, 'F1-Score': 0.803347280334728}]
# 15/15 [==============================] - 3s 161ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0.2}, {'Accuracy': 0.7913978494623656, 'Precision': 0.8042553191489362, 'Recall': 0.7875, 'F1-Score': 0.7957894736842105}]
# 15/15 [==============================] - 3s 161ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0.3}, {'Accuracy': 0.8021505376344086, 'Precision': 0.8363636363636363, 'Recall': 0.7666666666666667, 'F1-Score': 0.8}]
# 15/15 [==============================] - 5s 257ms/step
# [{'num_neurons_layer1': 128, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0.4}, {'Accuracy': 0.7763440860215054, 'Precision': 0.7764227642276422, 'Recall': 0.7958333333333333, 'F1-Score': 0.7860082304526749}]
# 15/15 [==============================] - 2s 107ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0, 'dropout_rate': 0}, {'Accuracy': 0.7784946236559139, 'Precision': 0.7565543071161048, 'Recall': 0.8416666666666667, 'F1-Score': 0.796844181459566}]
# 15/15 [==============================] - 2s 102ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0, 'dropout_rate': 0.1}, {'Accuracy': 0.7827956989247312, 'Precision': 0.7725490196078432, 'Recall': 0.8208333333333333, 'F1-Score': 0.7959595959595961}]
# 15/15 [==============================] - 2s 98ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0, 'dropout_rate': 0.2}, {'Accuracy': 0.7827956989247312, 'Precision': 0.7527272727272727, 'Recall': 0.8625, 'F1-Score': 0.8038834951456311}]
# 15/15 [==============================] - 2s 108ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0, 'dropout_rate': 0.3}, {'Accuracy': 0.7935483870967742, 'Precision': 0.7571428571428571, 'Recall': 0.8833333333333333, 'F1-Score': 0.8153846153846154}]
# 15/15 [==============================] - 2s 103ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0, 'dropout_rate': 0.4}, {'Accuracy': 0.789247311827957, 'Precision': 0.7709923664122137, 'Recall': 0.8416666666666667, 'F1-Score': 0.8047808764940239}]
# 15/15 [==============================] - 2s 108ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0}, {'Accuracy': 0.8021505376344086, 'Precision': 0.7803030303030303, 'Recall': 0.8583333333333333, 'F1-Score': 0.8174603174603174}]
# 15/15 [==============================] - 2s 101ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0.1}, {'Accuracy': 0.7784946236559139, 'Precision': 0.7686274509803922, 'Recall': 0.8166666666666667, 'F1-Score': 0.7919191919191919}]
# 15/15 [==============================] - 2s 104ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0.2}, {'Accuracy': 0.789247311827957, 'Precision': 0.7817460317460317, 'Recall': 0.8208333333333333, 'F1-Score': 0.8008130081300813}]
# 15/15 [==============================] - 3s 144ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0.3}, {'Accuracy': 0.7978494623655914, 'Precision': 0.7807692307692308, 'Recall': 0.8458333333333333, 'F1-Score': 0.8119999999999999}]
# 15/15 [==============================] - 2s 97ms/step
# [{'num_neurons_layer1': 64, 'spatial_dropout_rate': 0.2, 'dropout_rate': 0.4}, {'Accuracy': 0.7827956989247312, 'Precision': 0.7725490196078432, 'Recall': 0.8208333333333333, 'F1-Score': 0.7959595959595961}]

# %% [markdown]
# ### GRU

# %%
model_gru = Sequential()
model_gru.add(embedding_layer)
# model_gru.add(SpatialDropout1D(0.2))
model_gru.add(GRU(64, return_sequences = False))
model_gru.add(Dropout(0.2))
model_gru.add(Dense(1, activation = 'sigmoid'))
model_gru.summary()
# Out:
# Model: "sequential_51"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 300)         2455800
#
#  gru (GRU)                   (None, 64)                70272
#
#  dropout_41 (Dropout)        (None, 64)                0
#
#  dense_93 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 2526137 (9.64 MB)
# Trainable params: 70337 (274.75 KB)
# Non-trainable params: 2455800 (9.37 MB)
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model_gru.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model_gru.fit(X_train_padded_sequences, y_train, epochs=50, batch_size=32, validation_data=(X_test_padded_sequences, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/50
# 58/58 [==============================] - 11s 142ms/step - loss: 0.6670 - accuracy: 0.5906 - val_loss: 0.5892 - val_accuracy: 0.7312
# Epoch 2/50
# 58/58 [==============================] - 9s 163ms/step - loss: 0.4684 - accuracy: 0.7833 - val_loss: 0.4905 - val_accuracy: 0.7591
# Epoch 3/50
# 58/58 [==============================] - 10s 171ms/step - loss: 0.4126 - accuracy: 0.8144 - val_loss: 0.4965 - val_accuracy: 0.7935
# Epoch 4/50
# 58/58 [==============================] - 9s 153ms/step - loss: 0.3919 - accuracy: 0.8286 - val_loss: 0.4496 - val_accuracy: 0.7892
# Epoch 5/50
# 58/58 [==============================] - 9s 147ms/step - loss: 0.3710 - accuracy: 0.8330 - val_loss: 0.4445 - val_accuracy: 0.7849
# Epoch 6/50
# 58/58 [==============================] - 10s 167ms/step - loss: 0.3580 - accuracy: 0.8450 - val_loss: 0.4549 - val_accuracy: 0.7914
# Epoch 7/50
# 58/58 [==============================] - 9s 154ms/step - loss: 0.3542 - accuracy: 0.8483 - val_loss: 0.4463 - val_accuracy: 0.7871
# Epoch 8/50
# 58/58 [==============================] - 8s 136ms/step - loss: 0.3606 - accuracy: 0.8422 - val_loss: 0.4428 - val_accuracy: 0.7849
# Epoch 9/50
# 58/58 [==============================] - 10s 170ms/step - loss: 0.3572 - accuracy: 0.8428 - val_loss: 0.4983 - val_accuracy: 0.7677
# Epoch 10/50
# 58/58 [==============================] - 9s 156ms/step - loss: 0.3834 - accuracy: 0.8215 - val_loss: 0.4456 - val_accuracy: 0.7935
# Epoch 11/50
# 58/58 [==============================] - 8s 144ms/step - loss: 0.3503 - accuracy: 0.8493 - val_loss: 0.4509 - val_accuracy: 0.7957
# Epoch 12/50
# 58/58 [==============================] - 8s 140ms/step - loss: 0.3123 - accuracy: 0.8581 - val_loss: 0.4509 - val_accuracy: 0.7892
# Epoch 13/50
# 58/58 [==============================] - 10s 168ms/step - loss: 0.3047 - accuracy: 0.8668 - val_loss: 0.4666 - val_accuracy: 0.7957

# %%
y_pred_gru = model_gru.predict(X_test_padded_sequences)
y_pred_gru = (y_pred_gru > 0.5).astype(int)
get_report(y_test, y_pred_gru)
# Out:
# 15/15 [==============================] - 1s 39ms/step
# {'Accuracy': 0.7849462365591398,
#  'Precision': 0.75,
#  'Recall': 0.875,
#  'F1-Score': 0.8076923076923077}
