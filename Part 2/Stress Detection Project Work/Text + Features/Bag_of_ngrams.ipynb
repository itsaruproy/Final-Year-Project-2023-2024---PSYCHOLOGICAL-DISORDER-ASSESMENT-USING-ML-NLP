# %%
# !gdown 1OS2Aurb2oKmooCeYwYw0cnp542t7dyHo
# !gdown 1Oibb4sFzJNLt0iBWOD4LAIKaWT7cCNT1
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OS2Aurb2oKmooCeYwYw0cnp542t7dyHo
# To: /content/test_data.csv
# 100% 565k/565k [00:00<00:00, 85.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Oibb4sFzJNLt0iBWOD4LAIKaWT7cCNT1
# To: /content/train_data.csv
# 100% 2.24M/2.24M [00:00<00:00, 103MB/s]

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.preprocessing import MinMaxScaler

# %%
train_df = pd.read_csv("train_data.csv")
X_train = train_df.drop(['target'], axis=1)
y_train = train_df['target'].to_numpy()

# %%
test_df = pd.read_csv("test_data.csv")
X_test = test_df.drop(['target'], axis=1)
y_test = test_df['target'].to_numpy()

# %%
X_train.head()
# Out:
#    confidence  social_karma  syntax_ari  lex_liwc_WC  lex_liwc_Analytic  \
# 0    1.000000             3    5.311000           89              63.33
# 1    1.000000             3    4.220972          108              19.76
# 2    0.500000            15    5.548481           79              12.35
# 3    0.833333            18    4.352143           81              93.97
# 4    0.833333             4    7.366712          135              40.97
#
#    lex_liwc_Clout  lex_liwc_Authentic  lex_liwc_Tone  lex_liwc_WPS  \
# 0           10.84               98.92           3.83         17.80
# 1           11.45               95.96           1.00         15.43
# 2           44.98               69.44           1.00         15.80
# 3           40.24               99.00          25.77         16.20
# 4           72.32               75.74           1.00         27.00
#
#    lex_liwc_Sixltr  ...  lex_dal_min_activation  lex_dal_min_imagery  \
# 0            12.36  ...                  1.2222                  1.0
# 1            12.96  ...                  1.1429                  1.0
# 2            16.46  ...                  1.1429                  1.0
# 3            12.35  ...                  1.2000                  1.0
# 4            12.59  ...                  1.1429                  1.0
#
#    lex_dal_avg_activation  lex_dal_avg_imagery  lex_dal_avg_pleasantness  \
# 0                 1.74515              1.42143                   1.83704
# 1                 1.71501              1.57333                   1.85046
# 2                 1.80983              1.48267                   1.86705
# 3                 1.70892              1.84444                   1.81327
# 4                 1.75929              1.58319                   1.84228
#
#    social_upvote_ratio  social_num_comments  syntax_fk_grade  sentiment  \
# 0                 0.58                   27         6.376667   0.052071
# 1                 1.00                    0         5.593690  -0.022917
# 2                 0.91                    5         6.703646  -0.460000
# 3                 0.85                   11         5.150095   0.048636
# 4                 1.00                    5         7.778319   0.031250
#
#                                           clean_text
# 0  reluctant start one really ashamed ask help on...
# 1  severe addict overdose young addictionalcoholi...
# 2  feel sad feel sad pray get help desperately ne...
# 3  sleep car month month back foot stay parking s...
# 4  speed try catch continue yell face girl turn a...
#
# [5 rows x 110 columns]

# %% [markdown]
# # Bag Of Words

# %%
X_train_bow = X_train.drop(['clean_text'], axis=1).to_numpy()
X_test_bow = X_test.drop(['clean_text'], axis=1).to_numpy()

# %%
cv = CountVectorizer(max_features = 5000)

# %%
cv.fit(pd.concat([X_train['clean_text'], X_test['clean_text']],ignore_index=True))
# Out:
# CountVectorizer(max_features=5000)

# %%
train_bow = cv.transform(X_train['clean_text']).toarray()

# %%
X_train_bow = np.concatenate((X_train_bow, train_bow), axis=1)

# %%
test_bow = cv.transform(X_test['clean_text']).toarray()

# %%
X_test_bow = np.concatenate((X_test_bow, test_bow), axis=1)

# %%
print(X_train_bow.shape)
print(X_test_bow.shape)
# Out:
# (2842, 5109)
# (711, 5109)

# %% [markdown]
# # Training-Testing Phase

# %%
def training_and_prediction(training_model, X_train, X_test, y_train, y_test):
  model = training_model
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)
  recall = recall_score(y_test, y_pred)
  f1score = f1_score(y_test, y_pred)
  # print("Accuracy =", accuracy)
  # print("Confusion Matrix =\n", confusion_matrix(y_test, y_pred))
  # print(classification_report(y_test, y_pred))
  return {'Accuracy' : accuracy, 'Precision': precision, 'Recall' : recall, 'F1-Score' : f1score}

# %%
def get_report(y_test, y_pred):
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)
  recall = recall_score(y_test, y_pred)
  f1score = f1_score(y_test, y_pred)
  return {'Accuracy' : accuracy, 'Precision': precision, 'Recall' : recall, 'F1-Score' : f1score}

# %% [markdown]
# ## Naive Bayes

# %%
scaler = MinMaxScaler()
training_and_prediction(MultinomialNB(alpha=0.7), scaler.fit_transform(X_train_bow), scaler.fit_transform(X_test_bow), y_train, y_test)
# Out:
# {'Accuracy': 0.7327707454289732,
#  'Precision': 0.6885644768856448,
#  'Recall': 0.8202898550724638,
#  'F1-Score': 0.7486772486772488}

# %%
training_and_prediction(GaussianNB(), X_train_bow, X_test_bow, y_train, y_test)
# Out:
# {'Accuracy': 0.6315049226441631,
#  'Precision': 0.6,
#  'Recall': 0.7217391304347827,
#  'F1-Score': 0.6552631578947369}

# %%
training_and_prediction(BernoulliNB(alpha=0.3), X_train_bow, X_test_bow, y_train, y_test)
# Out:
# {'Accuracy': 0.7524613220815752,
#  'Precision': 0.7340720221606648,
#  'Recall': 0.7681159420289855,
#  'F1-Score': 0.7507082152974504}

# %% [markdown]
# ## SVM

# %%
# param_grid = {
#     'C': [0.1, 1, 10, 100],
#     'gamma': [0.001, 0.01, 0.1, 1],
#     'kernel': ['sigmoid', 'rbf', 'poly']
# }

# %%
# grid_search = GridSearchCV(estimator=SVC(), param_grid=param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
# grid_search.fit(X_train_bow, y_train)

# %%
# grid_search.best_estimator_

# %%
training_and_prediction(SVC(kernel='poly'), X_train_bow, X_test_bow, y_train, y_test)
# Out:
# {'Accuracy': 0.759493670886076,
#  'Precision': 0.7253886010362695,
#  'Recall': 0.8115942028985508,
#  'F1-Score': 0.7660738714090288}

# %% [markdown]
# ## Random Forest

# %%
# param_grid = {
#     'n_estimators': [100, 200, 300],
#     'max_depth': [None, 10, 20],
#     'min_samples_split': [2, 5, 10],
# }

# grid_search = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
# grid_search.fit(X_train_bow, y_train)
# print("Best Parameters:", grid_search.best_params_)
# print("Best Score:", grid_search.best_score_)

# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best Parameters: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 200}
# Best Score: 0.7631896829129433
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best Parameters: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 200}
# Best Score: 0.7631896829129433

# %%
training_and_prediction(RandomForestClassifier(min_samples_split=10, n_estimators=200), X_train_bow, X_test_bow, y_train, y_test)
# Out:
# {'Accuracy': 0.7524613220815752,
#  'Precision': 0.7302452316076294,
#  'Recall': 0.7768115942028986,
#  'F1-Score': 0.752808988764045}

# %% [markdown]
# ## Logistic Regression

# %%
# # Define the parameter grid
# param_grid = {
#     'penalty': ['l1', 'l2'],
#     'C': [0.001, 0.01, 0.1, 1, 10, 100],
#     'solver': ['liblinear', 'saga']
# }

# # Create a Logistic Regression classifier
# logistic_reg = LogisticRegression()

# # Initialize GridSearchCV
# grid_search = GridSearchCV(estimator=logistic_reg, param_grid=param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# # Perform grid search
# grid_search.fit(X_train_bow, y_train)

# # Print the best parameters and best score
# print("Best Parameters:", grid_search.best_params_)
# print("Best Score:", grid_search.best_score_)

# %%
training_and_prediction(LogisticRegression(max_iter=5000, solver='saga'), X_train_bow, X_test_bow, y_train, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# {'Accuracy': 0.7552742616033755,
#  'Precision': 0.7435897435897436,
#  'Recall': 0.7565217391304347,
#  'F1-Score': 0.7499999999999999}

# %% [markdown]
# ## Gredient Boosting

# %%
# param_grid = {
#     'learning_rate': [0.01, 0.1, 0.2],
#     'n_estimators': [100, 200, 300],
#     'max_depth': [3, 4, 5],
#     'subsample': [0.5, 0.7, 1.0],
#     'colsample_bytree': [0.5, 0.7, 1.0]
# }
# xgb_classifier = XGBClassifier()
# grid_search = GridSearchCV(estimator=xgb_classifier, param_grid=param_grid, cv=2, scoring='accuracy', verbose=2, n_jobs=-1)
# grid_search.fit(X_train_bow, y_train)
# print("Best Parameters:", grid_search.best_params_)
# print("Best Score:", grid_search.best_score_)

# Best Parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0}
# Best Score: 0.7638986629134412
# Out:
# Fitting 2 folds for each of 243 candidates, totalling 486 fits
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best Parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0}
# Best Score: 0.7638986629134412

# %%
training_and_prediction(XGBClassifier(colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0), X_train_bow, X_test_bow, y_train, y_test)
# Out:
# {'Accuracy': 0.7623066104078763,
#  'Precision': 0.7404371584699454,
#  'Recall': 0.7855072463768116,
#  'F1-Score': 0.7623066104078762}

# %% [markdown]
# ## Deep Learning Techniques with Word2vec

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Bidirectional, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### ANN

# %%
def ann_models(num_neurons_layer1, num_neurons_layer2, dropout_rate=0):
    model_dense = Sequential()
    model_dense.add(Dense(num_neurons_layer1, activation='relu', input_shape=(X_train_bow.shape[1],)))
    model_dense.add(Dropout(dropout_rate))
    model_dense.add(Dense(num_neurons_layer2, activation='relu'))
    model_dense.add(Dense(1, activation='sigmoid'))
    model_dense.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    model_dense.fit(X_train_bow, y_train, epochs=100, batch_size=32, verbose=0, callbacks=[early_stop], validation_data=(X_test_bow, y_test))
    y_pred_dense = model_dense.predict(X_test_bow)
    y_pred_dense = (y_pred_dense > 0.5).astype(int)
    return [{'num_neurons_layer1': num_neurons_layer1, 'num_neurons_layer2': num_neurons_layer2, 'dropout_rate': dropout_rate}, get_report(y_test, y_pred_dense)]

# %%
for num_neurons_layer1 in [256, 128, 64]:
  for num_neurons_layer2 in [64, 32]:
    for dropout_rate in [0.0, 0.1, 0.2, 0.3, 0.4]:
      print(ann_models(num_neurons_layer1, num_neurons_layer2, dropout_rate))
# Out:
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 64, 'dropout_rate': 0.0}, {'Accuracy': 0.7412095639943741, 'Precision': 0.7017543859649122, 'Recall': 0.8115942028985508, 'F1-Score': 0.7526881720430108}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 64, 'dropout_rate': 0.1}, {'Accuracy': 0.7609001406469761, 'Precision': 0.7410468319559229, 'Recall': 0.7797101449275362, 'F1-Score': 0.7598870056497176}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 64, 'dropout_rate': 0.2}, {'Accuracy': 0.770745428973277, 'Precision': 0.76, 'Recall': 0.7710144927536232, 'F1-Score': 0.7654676258992807}]
# 23/23 [==============================] - 0s 6ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 64, 'dropout_rate': 0.3}, {'Accuracy': 0.7791842475386779, 'Precision': 0.7919254658385093, 'Recall': 0.7391304347826086, 'F1-Score': 0.7646176911544228}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 64, 'dropout_rate': 0.4}, {'Accuracy': 0.7665260196905767, 'Precision': 0.7687687687687688, 'Recall': 0.7420289855072464, 'F1-Score': 0.7551622418879057}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 32, 'dropout_rate': 0.0}, {'Accuracy': 0.7777777777777778, 'Precision': 0.7876923076923077, 'Recall': 0.7420289855072464, 'F1-Score': 0.764179104477612}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 32, 'dropout_rate': 0.1}, {'Accuracy': 0.7735583684950773, 'Precision': 0.7628571428571429, 'Recall': 0.7739130434782608, 'F1-Score': 0.7683453237410072}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 32, 'dropout_rate': 0.2}, {'Accuracy': 0.7791842475386779, 'Precision': 0.79375, 'Recall': 0.736231884057971, 'F1-Score': 0.7639097744360901}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 32, 'dropout_rate': 0.3}, {'Accuracy': 0.7665260196905767, 'Precision': 0.7349081364829396, 'Recall': 0.8115942028985508, 'F1-Score': 0.7713498622589533}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 256, 'num_neurons_layer2': 32, 'dropout_rate': 0.4}, {'Accuracy': 0.7763713080168776, 'Precision': 0.7687861271676301, 'Recall': 0.7710144927536232, 'F1-Score': 0.7698986975397974}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.0}, {'Accuracy': 0.739803094233474, 'Precision': 0.679372197309417, 'Recall': 0.8782608695652174, 'F1-Score': 0.7661188369152971}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.1}, {'Accuracy': 0.7749648382559775, 'Precision': 0.7846153846153846, 'Recall': 0.7391304347826086, 'F1-Score': 0.7611940298507462}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.2}, {'Accuracy': 0.7665260196905767, 'Precision': 0.7136038186157518, 'Recall': 0.8666666666666667, 'F1-Score': 0.7827225130890053}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.3}, {'Accuracy': 0.7693389592123769, 'Precision': 0.7479452054794521, 'Recall': 0.7913043478260869, 'F1-Score': 0.7690140845070422}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 64, 'dropout_rate': 0.4}, {'Accuracy': 0.7566807313642757, 'Precision': 0.7128712871287128, 'Recall': 0.8347826086956521, 'F1-Score': 0.7690253671562083}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.0}, {'Accuracy': 0.7679324894514767, 'Precision': 0.7295918367346939, 'Recall': 0.8289855072463768, 'F1-Score': 0.7761194029850746}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.1}, {'Accuracy': 0.759493670886076, 'Precision': 0.7253886010362695, 'Recall': 0.8115942028985508, 'F1-Score': 0.7660738714090288}]
# 23/23 [==============================] - 1s 3ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.2}, {'Accuracy': 0.7637130801687764, 'Precision': 0.7827476038338658, 'Recall': 0.7101449275362319, 'F1-Score': 0.7446808510638299}]
# 23/23 [==============================] - 0s 4ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.3}, {'Accuracy': 0.7665260196905767, 'Precision': 0.7549857549857549, 'Recall': 0.7681159420289855, 'F1-Score': 0.7614942528735632}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 128, 'num_neurons_layer2': 32, 'dropout_rate': 0.4}, {'Accuracy': 0.759493670886076, 'Precision': 0.75, 'Recall': 0.7565217391304347, 'F1-Score': 0.7532467532467532}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.0}, {'Accuracy': 0.7609001406469761, 'Precision': 0.7725856697819314, 'Recall': 0.7188405797101449, 'F1-Score': 0.7447447447447447}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.1}, {'Accuracy': 0.7609001406469761, 'Precision': 0.7345844504021448, 'Recall': 0.7942028985507247, 'F1-Score': 0.7632311977715878}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.2}, {'Accuracy': 0.7693389592123769, 'Precision': 0.7520891364902507, 'Recall': 0.782608695652174, 'F1-Score': 0.7670454545454545}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.3}, {'Accuracy': 0.7552742616033755, 'Precision': 0.7381615598885793, 'Recall': 0.7681159420289855, 'F1-Score': 0.7528409090909091}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 64, 'dropout_rate': 0.4}, {'Accuracy': 0.7721518987341772, 'Precision': 0.7577464788732394, 'Recall': 0.7797101449275362, 'F1-Score': 0.7685714285714286}]
# 23/23 [==============================] - 0s 3ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.0}, {'Accuracy': 0.7777777777777778, 'Precision': 0.7931034482758621, 'Recall': 0.7333333333333333, 'F1-Score': 0.7620481927710843}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.1}, {'Accuracy': 0.7637130801687764, 'Precision': 0.797979797979798, 'Recall': 0.6869565217391305, 'F1-Score': 0.7383177570093458}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.2}, {'Accuracy': 0.7693389592123769, 'Precision': 0.7854889589905363, 'Recall': 0.7217391304347827, 'F1-Score': 0.7522658610271904}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.3}, {'Accuracy': 0.759493670886076, 'Precision': 0.7242268041237113, 'Recall': 0.8144927536231884, 'F1-Score': 0.7667121418826739}]
# 23/23 [==============================] - 0s 2ms/step
# [{'num_neurons_layer1': 64, 'num_neurons_layer2': 32, 'dropout_rate': 0.4}, {'Accuracy': 0.7693389592123769, 'Precision': 0.7734138972809668, 'Recall': 0.7420289855072464, 'F1-Score': 0.757396449704142}]
