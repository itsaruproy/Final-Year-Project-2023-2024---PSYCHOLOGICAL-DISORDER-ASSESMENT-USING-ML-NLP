# %%
# !pipenv install -e git+https://github.com/dfederschmidt/pyliwc#egg=pyliwc
# Out:
# /bin/bash: line 1: pipenv: command not found

# %%
from pyliwc.core import LIWC
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-d095068d608b> in <cell line: 1>()
# ----> 1 from pyliwc.core import LIWC
#       2
#
# ModuleNotFoundError: No module named 'pyliwc'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
blob.sentiment.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-9040fca834d9> in <cell line: 1>()
# ----> 1 blob.sentiment.func
#
# AttributeError: 'Sentiment' object has no attribute 'func'
